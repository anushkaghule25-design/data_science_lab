# %% [markdown]
# <a href="https://colab.research.google.com/github/anushkaghule25-design/data_science_lab/blob/main/Palindrome.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def is_palindrome(number):
    num_str = str(number)
    if num_str == num_str[::-1]:
        return f"{number} is a palindrome."
    else:
        return f"{number} is not a palindrome."

num = input("Enter a number: ")

print(is_palindrome(num))
# Out:
# Enter a number: 121
# 121 is a palindrome.
