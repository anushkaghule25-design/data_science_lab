# %% [markdown]
# <a href="https://colab.research.google.com/github/anushkaghule25-design/data_science_lab/blob/main/PR4TH_C_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

tosses = int(input("Enter number of tosses: "))
heads = 0
tails = 0

for i in range(tosses):
    result = random.choice(["H", "T"])
    if result == "H":
        heads += 1
    else:
        tails += 1

prob_heads = heads / tosses
prob_tails = tails / tosses

print("Total Tosses:", tosses)
print("Heads:", heads)
print("Tails:", tails)
print("Probability of Heads:", prob_heads)
print("Probability of Tails:", prob_tails)
# Out:
# Enter number of tosses: 2
# Total Tosses: 2
# Heads: 2
# Tails: 0
# Probability of Heads: 1.0
# Probability of Tails: 0.0
