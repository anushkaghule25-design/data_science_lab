# %% [markdown]
# <a href="https://colab.research.google.com/github/anushkaghule25-design/data_science_lab/blob/main/BFS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import deque

# Graph example
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': [],
    'F': []
}

# BFS function
def bfs(graph, start):
    visited = []        # to store visited nodes
    queue = deque([start])   # queue for BFS

    while queue:
        node = queue.popleft()

        if node not in visited:
            visited.append(node)

            # add neighbors to queue
            for neighbor in graph[node]:
                queue.append(neighbor)

    return visited

# Run BFS
result = bfs(graph, 'A')
print("BFS Traversal:", result)
# Out:
# BFS Traversal: ['A', 'B', 'C', 'D', 'E', 'F']
